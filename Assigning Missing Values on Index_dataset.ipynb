# %%
import pandas as pd

# %%
dataset = pd.read_excel(r"D:\Kaggle datasets\index.xlsx")
dataset
# Out:
#            date                datetime cash_type                 card  money  \
# 0    2024-03-01 2024-03-01 10:15:50.520      card  ANON-0000-0000-0001  38.70
# 1    2024-03-01 2024-03-01 12:19:22.539      card  ANON-0000-0000-0002  38.70
# 2    2024-03-01 2024-03-01 12:20:18.089      card  ANON-0000-0000-0002  38.70
# 3    2024-03-01 2024-03-01 13:46:33.006      card  ANON-0000-0000-0003  28.90
# 4    2024-03-01 2024-03-01 13:48:14.626      card  ANON-0000-0000-0004  38.70
# ...         ...                     ...       ...                  ...    ...
# 2021 2024-10-20 2024-10-20 21:14:18.045      card  ANON-0000-0000-0789  35.76
# 2022 2024-10-20 2024-10-20 21:15:17.780      card  ANON-0000-0000-0790  25.96
# 2023 2024-10-20 2024-10-20 21:17:26.865      card  ANON-0000-0000-0791  35.76
# 2024 2024-10-20 2024-10-20 21:25:00.085      card  ANON-0000-0000-0792  35.76
# 2025 2024-10-20 2024-10-20 22:17:29.041      card  ANON-0000-0000-0550  35.76
#
#         coffee_name
# ...

# %%
dataset.head(20)
# Out:
#          date                datetime cash_type                 card  money  \
# 0  2024-03-01 2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01 2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01 2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01 2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01 2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
# 5  2024-03-01 2024-03-01 15:39:47.726      card  ANON-0000-0000-0005   33.8
# 6  2024-03-01 2024-03-01 16:19:02.756      card  ANON-0000-0000-0006   38.7
# 7  2024-03-01 2024-03-01 18:39:03.580      card  ANON-0000-0000-0007   33.8
# 8  2024-03-01 2024-03-01 19:22:01.762      card  ANON-0000-0000-0008   38.7
# 9  2024-03-01 2024-03-01 19:23:15.887      card  ANON-0000-0000-0008   33.8
# 10 2024-03-01 2024-03-01 19:29:17.391      card  ANON-0000-0000-0009    NaN
# ...

# %%
dataset.shape
# Out:
# (2026, 6)

# %%
dataset.isnull().sum().sum()
# Out:
# 96

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# date           0.000000
# datetime       0.000000
# cash_type      0.000000
# card           4.392892
# money          0.148075
# coffee_name    0.197433
# dtype: float64

# %%
(dataset.isnull().sum().sum()/(dataset.shape[0]*dataset.shape[1]))
# Out:
# 0.007897334649555774

# %% [markdown]
# # Fill miss data row wise

# %%
dataset.fillna(20).head(50)
# Out:
#          date                datetime cash_type                 card  money  \
# 0  2024-03-01 2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01 2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01 2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01 2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01 2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
# 5  2024-03-01 2024-03-01 15:39:47.726      card  ANON-0000-0000-0005   33.8
# 6  2024-03-01 2024-03-01 16:19:02.756      card  ANON-0000-0000-0006   38.7
# 7  2024-03-01 2024-03-01 18:39:03.580      card  ANON-0000-0000-0007   33.8
# 8  2024-03-01 2024-03-01 19:22:01.762      card  ANON-0000-0000-0008   38.7
# 9  2024-03-01 2024-03-01 19:23:15.887      card  ANON-0000-0000-0008   33.8
# 10 2024-03-01 2024-03-01 19:29:17.391      card  ANON-0000-0000-0009   20.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2026 entries, 0 to 2025
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         2026 non-null   datetime64[ns]
#  1   datetime     2026 non-null   datetime64[ns]
#  2   cash_type    2026 non-null   object
#  3   card         1937 non-null   object
#  4   money        2023 non-null   float64
#  5   coffee_name  2022 non-null   object
# dtypes: datetime64[ns](2), float64(1), object(3)
# memory usage: 95.1+ KB

# %% [markdown]
# # Fill data through backward filling.

# %%
dataset.fillna(method="bfill").head(50)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_28636\3371710933.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="bfill").head(50)
#          date                datetime cash_type                 card  money  \
# 0  2024-03-01 2024-03-01 10:15:50.520      card  ANON-0000-0000-0001   38.7
# 1  2024-03-01 2024-03-01 12:19:22.539      card  ANON-0000-0000-0002   38.7
# 2  2024-03-01 2024-03-01 12:20:18.089      card  ANON-0000-0000-0002   38.7
# 3  2024-03-01 2024-03-01 13:46:33.006      card  ANON-0000-0000-0003   28.9
# 4  2024-03-01 2024-03-01 13:48:14.626      card  ANON-0000-0000-0004   38.7
# 5  2024-03-01 2024-03-01 15:39:47.726      card  ANON-0000-0000-0005   33.8
# 6  2024-03-01 2024-03-01 16:19:02.756      card  ANON-0000-0000-0006   38.7
# 7  2024-03-01 2024-03-01 18:39:03.580      card  ANON-0000-0000-0007   33.8
# ...

# %% [markdown]
# # Fill data through forward filling.

# %%
dataset.fillna(method="ffill",inplace = True).tail(50)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_28636\955788656.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="ffill",inplace = True).tail(50)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 dataset.fillna(method="ffill",inplace = True).tail(50)
#
# AttributeError: 'NoneType' object has no attribute 'tail'

# %%
dataset.isnull().sum()
# Out:
# date           0
# datetime       0
# cash_type      0
# card           0
# money          0
# coffee_name    0
# dtype: int64

# %%
# dataset["coffee_name"].mode()[0]

# %%
# dataset["coffee_name"]=dataset["coffee_name"].fillna(dataset["coffee_name"].mode()[0]).head(100)

# %%
# dataset.select_dtypes(include="object")

# %%
# for i in dataset.select_dtypes(include="object").columns:
    # dataset[i].fillna(dataset[i].mode()[0])

# %%
dataset.shape
# Out:
# (2026, 6)

# %%
dataset.isnull().sum().sum()
# Out:
# 0
