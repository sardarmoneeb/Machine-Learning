# %%
import pandas as pd

# %%
dataset=pd.read_excel(r"D:\Kaggle datasets\Boston.xlsx")

# %%
dataset.head(10)
# Out:
#    Unnamed: 0     crim    zn  indus  chas    nox     rm    age     dis  rad  \
# 0           1  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1
# 1           2  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2
# 2           3  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2
# 3           4  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3
# 4           5  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3
# 5           6  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3
# 6           7  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5
# 7           8  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5
# 8           9  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5
# 9          10  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5
#
#    tax  ptratio   black  lstat  medv
# 0  296     15.3  396.90   4.98  24.0
# 1  242     17.8  396.90   9.14  21.6
# 2  242     17.8  392.83   4.03  34.7
# 3  222     18.7  394.63   2.94  33.4
# 4  222     18.7  396.90   5.33  36.2
# 5  222     18.7  394.12   5.21  28.7
# 6  311     15.2  395.60  12.43  22.9
# 7  311     15.2  396.90  19.15  27.1
# 8  311     15.2  386.63  29.93  16.5
# 9  311     15.2  386.71  17.10  18.9

# %%
dataset.shape
# Out:
# (506, 15)

# %%
input_data = dataset.iloc[:,:-1]
output_data = dataset["medv"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(input_data,output_data,test_size=0.25)

# %%
x_train
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 290         291  0.03502  80.0   4.95     0  0.411  6.861  27.9  5.1167    4
# 230         231  0.53700   0.0   6.20     0  0.504  5.981  68.1  3.6715    8
# 176         177  0.07022   0.0   4.05     0  0.510  6.020  47.2  3.5549    5
# 472         473  3.56868   0.0  18.10     0  0.580  6.437  75.0  2.8965   24
# 77           78  0.08707   0.0  12.83     0  0.437  6.140  45.8  4.0905    5
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 131         132  1.19294   0.0  21.89     0  0.624  6.326  97.7  2.2710    4
# 267         268  0.57834  20.0   3.97     0  0.575  8.297  67.0  2.4216    5
# 82           83  0.03659  25.0   4.86     0  0.426  6.302  32.2  5.4007    4
# 211         212  0.37578   0.0  10.59     1  0.489  5.404  88.6  3.6650    4
# 421         422  7.02259   0.0  18.10     0  0.718  6.006  95.3  1.8746   24
#
#      tax  ptratio   black  lstat
# 290  245     19.2  396.90   3.33
# 230  307     17.4  378.35  11.65
# 176  296     16.6  393.23  10.11
# 472  666     20.2  393.37  14.36
# 77   398     18.7  386.96  10.27
# ..   ...      ...     ...    ...
# 131  437     21.2  396.90  12.26
# 267  264     13.0  384.54   7.44
# 82   281     19.0  396.90   6.72
# 211  277     18.6  395.24  23.98
# 421  666     20.2  319.98  15.70
#
# [379 rows x 14 columns]

# %%
x_train.shape
# Out:
# (379, 14)

# %%
x_test.shape
# Out:
# (127, 14)

# %%
y_train.shape
# Out:
# (379,)

# %%
y_test.shape
# Out:
# (127,)
